# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from os import chdir

# %%
chdir('/content/drive/MyDrive/pantanal.dev/artificial-intelligence/datasets')

# %%
label_dict = {
    'Positivo': 2,
    'Neutro': 1,
    'Negativo': 0
}

def process_google_label(label):
    try:
        print(label, end='|')
        label_split = label.split(' ')
        print(label_split, end='|')
        label = label_split[-1]
        print(label, end='|')
        if label in label_dict.keys():
            label = label_dict[label]
            print(label)
        print()
        return label
    except AttributeError:
        return None

# %% [markdown]
# # Português

# %%
base_df = pd.read_excel('google-news/google-news-ptbr-labelled.xlsx', index_col=0)
base_df
# Out:
# /usr/local/lib/python3.9/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                                   text  label  lang
# 0    Em surto nas redes, CEO da Hurb xinga clientes...      0  ptbr
# 1    CEO da Hurb xinga cliente, expõe dados e faz a...      0  ptbr
# 2    Devendo para hotéis de Gramado e Canela, CEO d...      0  ptbr
# 3    Calotes, ameaças e deboche: entenda a crise na...      0  ptbr
# 4    Mega-Sena acumula e deve pagar R$ 50 milhões n...      1  ptbr
# ..                                                 ...    ...   ...
# 375  Volta do receio com bancos e queda das commodi...      0  ptbr
# 376  Arrecadação federal atinge R$ 171,06 bilhões e...      2  ptbr
# 377  Ford inicia teste da fábrica da Nova Ranger co...      2  ptbr
# 378  ATUALIZADO! Calendário do Bolsa Família convoc...      1  ptbr
# ...

# %%
def get_news(url):
    response = requests.get(url)

    if response.status_code != 200:
        print(f"Falha na solicitação, código de status: {response.status_code}")
    else:
        print("Solicitação bem-sucedida")

        soup = BeautifulSoup(response.content, 'html')
        h4_elements = soup.find_all('h4', {'class': 'gPFEn'})
        texts = [h4.text for h4 in h4_elements]
        
        df = pd.DataFrame(columns=['text', 'label'])
        df['text'] = texts

        return df

# %%
ptbr_url = 'https://news.google.com/topics/CAAqKggKIiRDQkFTRlFvSUwyMHZNRGx6TVdZU0JYQjBMVUpTR2dKQ1VpZ0FQAQ?hl=pt-BR&gl=BR&ceid=BR%3Apt-419'

# %%
df_ptbr = get_news(ptbr_url)
# Out:
# Solicitação bem-sucedida

# %%
df_ptbr
# Out:
#                                                   text label
# 0     Ibovespa: 4 fatores que pesam sobre a Bolsa hoje   NaN
# 1    Após audiência de presidente do BC, dólar sobe...   NaN
# 2    Ibovespa Futuro cai, seguindo exterior e com i...   NaN
# 3    Ibovespa voltou a fechar em queda nesta terça-...   NaN
# 4    Tesouro Direto: juros mantêm queda, com IPCA+2...   NaN
# ..                                                 ...   ...
# 213  GWM e governo de São Paulo fecham acordo para ...   NaN
# 214  Será que a Honda trapaceou no recorde do Type ...   NaN
# 215  Honda Civic Type-R desembarca no Brasil com co...   NaN
# 216  5 coisas que sabemos do Honda Civic Type R 202...   NaN
# 217          Novo Honda Civic Type R já está no Brasil   NaN
#
# [218 rows x 2 columns]

# %%
df_ptbr = pd.concat([base_df, df_ptbr], ignore_index=True)
df_ptbr.drop_duplicates(subset='text', inplace=True)
df_ptbr.reset_index(drop=True, inplace=True)
df_ptbr['lang'] = 'ptbr'
df_ptbr
# Out:
#                                                   text label  lang
# 0    Em surto nas redes, CEO da Hurb xinga clientes...     0  ptbr
# 1    CEO da Hurb xinga cliente, expõe dados e faz a...     0  ptbr
# 2    Devendo para hotéis de Gramado e Canela, CEO d...     0  ptbr
# 3    Calotes, ameaças e deboche: entenda a crise na...     0  ptbr
# 4    Mega-Sena acumula e deve pagar R$ 50 milhões n...     1  ptbr
# ..                                                 ...   ...   ...
# 447  Calote dos EUA: Entenda as consequências de um...   NaN  ptbr
# 448  Calote da dívida dos EUA desencadearia uma "ca...   NaN  ptbr
# 449  Itaú testa ferramenta que possibilita que os c...   NaN  ptbr
# 450  Bom dia, Bitcoin (BTC): semana começa em queda...   NaN  ptbr
# 451  O novo arcabouço fiscal e a trilha para o dese...   NaN  ptbr
#
# [452 rows x 3 columns]

# %%
df_ptbr['label'] = pd.to_numeric(df_ptbr['label'], errors='coerce').astype('Int64')
df_ptbr
# Out:
#                                                   text  label  lang
# 0    Em surto nas redes, CEO da Hurb xinga clientes...      0  ptbr
# 1    CEO da Hurb xinga cliente, expõe dados e faz a...      0  ptbr
# 2    Devendo para hotéis de Gramado e Canela, CEO d...      0  ptbr
# 3    Calotes, ameaças e deboche: entenda a crise na...      0  ptbr
# 4    Mega-Sena acumula e deve pagar R$ 50 milhões n...      1  ptbr
# ..                                                 ...    ...   ...
# 447  Calote dos EUA: Entenda as consequências de um...   <NA>  ptbr
# 448  Calote da dívida dos EUA desencadearia uma "ca...   <NA>  ptbr
# 449  Itaú testa ferramenta que possibilita que os c...   <NA>  ptbr
# 450  Bom dia, Bitcoin (BTC): semana começa em queda...   <NA>  ptbr
# 451  O novo arcabouço fiscal e a trilha para o dese...   <NA>  ptbr
#
# [452 rows x 3 columns]

# %%
df_ptbr.dropna(inplace=True)
df_ptbr
# Out:
#                                                   text  label  lang
# 0    Em surto nas redes, CEO da Hurb xinga clientes...      0  ptbr
# 1    CEO da Hurb xinga cliente, expõe dados e faz a...      0  ptbr
# 2    Devendo para hotéis de Gramado e Canela, CEO d...      0  ptbr
# 3    Calotes, ameaças e deboche: entenda a crise na...      0  ptbr
# 4    Mega-Sena acumula e deve pagar R$ 50 milhões n...      1  ptbr
# ..                                                 ...    ...   ...
# 375  Volta do receio com bancos e queda das commodi...      0  ptbr
# 376  Arrecadação federal atinge R$ 171,06 bilhões e...      2  ptbr
# 377  Ford inicia teste da fábrica da Nova Ranger co...      2  ptbr
# 378  ATUALIZADO! Calendário do Bolsa Família convoc...      1  ptbr
# 379  IMPOSTO DE RENDA 2023: até QUANDO vai PRAZO pa...      1  ptbr
#
# [380 rows x 3 columns]

# %%
df_ptbr['label'].value_counts()
# Out:
# 0    149
# 2    127
# 1    104
# Name: label, dtype: Int64

# %%
df_ptbr.to_csv('google-news/google-news-ptbr.csv', sep='|')

# %% [markdown]
# # Inglês

# %%
base_eng_df = pd.read_excel('google-news/google-news-eng-labelled.xlsx')
base_eng_df
# Out:
# /usr/local/lib/python3.9/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      Unnamed: 0                                               text  \
# 0             0  NBCUniversal boss Jeff Shell out after 'inappr...
# 1             1  NBCUniversal CEO stepping down over 'inappropr...
# 2             2  NBCUniversal CEO Jeff Shell steps down followi...
# 3             3  Jeff Shell Ousted at NBCUniversal for ‘Inappro...
# 4             4  Bed Bath & Beyond is closing. Here's how it af...
# ..          ...                                                ...
# 449         449  New 1-Day Volatility Index will open many door...
# 450         450  Yellen Says US Default Would Cause an 'Economi...
# 451         451  US default on debt would trigger an 'economic ...
# 452         452  Yellen warns debt default would disrupt Social...
# ...

# %%
eng_url = 'https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx6TVdZU0FtVnVHZ0pWVXlnQVAB?hl=en-US&gl=US&ceid=US%3Aen'

# %%
df_eng = get_news(eng_url)
# Out:
# Solicitação bem-sucedida

# %%
df_eng
# Out:
#                                                   text label
# 0    First Republic Bank Shares Sink 49% After Earn...   NaN
# 1    First Republic Bank's deposit outflows were wo...   NaN
# 2    First Republic falls nearly 50% to record low ...   NaN
# 3       First Republic May Sell $100 Billion in Assets   NaN
# 4    Chipotle Stock Sizzles After Earnings, Revenue...   NaN
# ..                                                 ...   ...
# 267  Financial Challenges 'Clobber' New York City's...   NaN
# 268  Luxury goods giant LVMH becomes the first Euro...   NaN
# 269  LVMH market cap milestone: First European comp...   NaN
# 270        LVMH posted record growth as China reopened   NaN
# 271  LVMH becomes Europe's most valuable company at...   NaN
#
# [272 rows x 2 columns]

# %%
df_eng = pd.concat([base_eng_df, df_eng], ignore_index=True)
df_eng.drop_duplicates(subset='text', inplace=True)
df_eng.reset_index(drop=True, inplace=True)
df_eng.drop(columns='Unnamed: 0', inplace=True)
df_eng['lang'] = 'eng'
df_eng
# Out:
#                                                   text label lang
# 0    NBCUniversal boss Jeff Shell out after 'inappr...     0  eng
# 1    NBCUniversal CEO stepping down over 'inappropr...     0  eng
# 2    NBCUniversal CEO Jeff Shell steps down followi...     0  eng
# 3    Jeff Shell Ousted at NBCUniversal for ‘Inappro...     0  eng
# 4    Bed Bath & Beyond is closing. Here's how it af...     0  eng
# ..                                                 ...   ...  ...
# 557  Financial Challenges 'Clobber' New York City's...   NaN  eng
# 558  Luxury goods giant LVMH becomes the first Euro...   NaN  eng
# 559  LVMH market cap milestone: First European comp...   NaN  eng
# 560        LVMH posted record growth as China reopened   NaN  eng
# 561  LVMH becomes Europe's most valuable company at...   NaN  eng
#
# [562 rows x 3 columns]

# %%
df_eng['label'] = df_eng['label'].apply(process_google_label)
df_eng
# Out:
#                                                   text label lang
# 0    NBCUniversal boss Jeff Shell out after 'inappr...     0  eng
# 1    NBCUniversal CEO stepping down over 'inappropr...     0  eng
# 2    NBCUniversal CEO Jeff Shell steps down followi...     0  eng
# 3    Jeff Shell Ousted at NBCUniversal for ‘Inappro...     0  eng
# 4    Bed Bath & Beyond is closing. Here's how it af...     0  eng
# ..                                                 ...   ...  ...
# 557  Financial Challenges 'Clobber' New York City's...  None  eng
# 558  Luxury goods giant LVMH becomes the first Euro...  None  eng
# 559  LVMH market cap milestone: First European comp...  None  eng
# 560        LVMH posted record growth as China reopened  None  eng
# 561  LVMH becomes Europe's most valuable company at...  None  eng
#
# [562 rows x 3 columns]

# %%
df_eng['label'] = pd.to_numeric(df_eng['label'], errors='coerce').astype('Int64')
df_eng
# Out:
#                                                   text  label lang
# 0    NBCUniversal boss Jeff Shell out after 'inappr...      0  eng
# 1    NBCUniversal CEO stepping down over 'inappropr...      0  eng
# 2    NBCUniversal CEO Jeff Shell steps down followi...      0  eng
# 3    Jeff Shell Ousted at NBCUniversal for ‘Inappro...      0  eng
# 4    Bed Bath & Beyond is closing. Here's how it af...      0  eng
# ..                                                 ...    ...  ...
# 557  Financial Challenges 'Clobber' New York City's...   <NA>  eng
# 558  Luxury goods giant LVMH becomes the first Euro...   <NA>  eng
# 559  LVMH market cap milestone: First European comp...   <NA>  eng
# 560        LVMH posted record growth as China reopened   <NA>  eng
# 561  LVMH becomes Europe's most valuable company at...   <NA>  eng
#
# [562 rows x 3 columns]

# %%
df_eng.dropna(inplace=True)
df_eng
# Out:
#                                                   text  label lang
# 0    NBCUniversal boss Jeff Shell out after 'inappr...      0  eng
# 1    NBCUniversal CEO stepping down over 'inappropr...      0  eng
# 2    NBCUniversal CEO Jeff Shell steps down followi...      0  eng
# 3    Jeff Shell Ousted at NBCUniversal for ‘Inappro...      0  eng
# 4    Bed Bath & Beyond is closing. Here's how it af...      0  eng
# ..                                                 ...    ...  ...
# 449  New 1-Day Volatility Index will open many door...      0  eng
# 450  Yellen Says US Default Would Cause an 'Economi...      0  eng
# 451  US default on debt would trigger an 'economic ...      0  eng
# 452  Yellen warns debt default would disrupt Social...      0  eng
# 453  Debt limit action should be 'without condition...      1  eng
#
# [454 rows x 3 columns]

# %%
df_eng.to_csv('google-news/google-news-eng.csv', sep='|')

# %% [markdown]
# # Concatenar datasets

# %%
df_ptbr = pd.read_csv('google-news/google-news-ptbr.csv', sep='|', index_col=0)
df_eng = pd.read_csv('google-news/google-news-eng.csv', sep='|', index_col=0)

# %%
df_ptbr
# Out:
#                                                   text  label  lang
# 0    Em surto nas redes, CEO da Hurb xinga clientes...      0  ptbr
# 1    CEO da Hurb xinga cliente, expõe dados e faz a...      0  ptbr
# 2    Devendo para hotéis de Gramado e Canela, CEO d...      0  ptbr
# 3    Calotes, ameaças e deboche: entenda a crise na...      0  ptbr
# 4    Mega-Sena acumula e deve pagar R$ 50 milhões n...      1  ptbr
# ..                                                 ...    ...   ...
# 375  Volta do receio com bancos e queda das commodi...      0  ptbr
# 376  Arrecadação federal atinge R$ 171,06 bilhões e...      2  ptbr
# 377  Ford inicia teste da fábrica da Nova Ranger co...      2  ptbr
# 378  ATUALIZADO! Calendário do Bolsa Família convoc...      1  ptbr
# 379  IMPOSTO DE RENDA 2023: até QUANDO vai PRAZO pa...      1  ptbr
#
# [380 rows x 3 columns]

# %%
df_eng
# Out:
#                                                   text  label lang
# 0    NBCUniversal boss Jeff Shell out after 'inappr...      0  eng
# 1    NBCUniversal CEO stepping down over 'inappropr...      0  eng
# 2    NBCUniversal CEO Jeff Shell steps down followi...      0  eng
# 3    Jeff Shell Ousted at NBCUniversal for ‘Inappro...      0  eng
# 4    Bed Bath & Beyond is closing. Here's how it af...      0  eng
# ..                                                 ...    ...  ...
# 449  New 1-Day Volatility Index will open many door...      0  eng
# 450  Yellen Says US Default Would Cause an 'Economi...      0  eng
# 451  US default on debt would trigger an 'economic ...      0  eng
# 452  Yellen warns debt default would disrupt Social...      0  eng
# 453  Debt limit action should be 'without condition...      1  eng
#
# [454 rows x 3 columns]

# %%
google_news_df = pd.concat([df_ptbr, df_eng], ignore_index=True)
google_news_df
# Out:
#                                                   text  label  lang
# 0    Em surto nas redes, CEO da Hurb xinga clientes...      0  ptbr
# 1    CEO da Hurb xinga cliente, expõe dados e faz a...      0  ptbr
# 2    Devendo para hotéis de Gramado e Canela, CEO d...      0  ptbr
# 3    Calotes, ameaças e deboche: entenda a crise na...      0  ptbr
# 4    Mega-Sena acumula e deve pagar R$ 50 milhões n...      1  ptbr
# ..                                                 ...    ...   ...
# 829  New 1-Day Volatility Index will open many door...      0   eng
# 830  Yellen Says US Default Would Cause an 'Economi...      0   eng
# 831  US default on debt would trigger an 'economic ...      0   eng
# 832  Yellen warns debt default would disrupt Social...      0   eng
# 833  Debt limit action should be 'without condition...      1   eng
#
# [834 rows x 3 columns]

# %%
google_news_df['font'] = 'google-news'
google_news_df
# Out:
#                                                   text  label  lang  \
# 0    Em surto nas redes, CEO da Hurb xinga clientes...      0  ptbr
# 1    CEO da Hurb xinga cliente, expõe dados e faz a...      0  ptbr
# 2    Devendo para hotéis de Gramado e Canela, CEO d...      0  ptbr
# 3    Calotes, ameaças e deboche: entenda a crise na...      0  ptbr
# 4    Mega-Sena acumula e deve pagar R$ 50 milhões n...      1  ptbr
# ..                                                 ...    ...   ...
# 829  New 1-Day Volatility Index will open many door...      0   eng
# 830  Yellen Says US Default Would Cause an 'Economi...      0   eng
# 831  US default on debt would trigger an 'economic ...      0   eng
# 832  Yellen warns debt default would disrupt Social...      0   eng
# 833  Debt limit action should be 'without condition...      1   eng
#
#             font
# 0    google-news
# 1    google-news
# 2    google-news
# 3    google-news
# 4    google-news
# ..           ...
# 829  google-news
# ...

# %%
google_news_df['label'].value_counts()
# Out:
# 0    326
# 2    258
# 1    250
# Name: label, dtype: int64

# %%
google_news_df['lang'].value_counts()
# Out:
# eng     454
# ptbr    380
# Name: lang, dtype: int64

# %%
google_news_df.to_csv('google-news/google-news.csv')
