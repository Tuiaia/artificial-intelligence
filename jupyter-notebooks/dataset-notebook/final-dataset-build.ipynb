# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
REPO_DIR = '/content/drive/Othercomputers/Desktop/pantanal.dev/artificial-intelligence'

# %%
from os import chdir
chdir(REPO_DIR)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# !pip install nltk
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.2.0)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
seed = 42
np.random.seed(seed)

# %% [markdown]
# # Carregar datasets
# * infomoney (ptbr)
# * google-news (ptbr, eng)
# * financial-phrase-bank (ptbr, eng)
# * b3 (ptbr)

# %%
infomoney_path = 'datasets/infomoney/infomoney_news_labelled_cleaned.csv'
google_news_path = 'datasets/google-news/google-news-labelled.csv'
financial_phrase_bank_path = 'datasets/financial-phrase-bank/financial-phrase-bank.csv'
b3_path = 'datasets/b3/b3-labelled.csv'

# %%
infomoney_df = pd.read_csv(infomoney_path)
google_news_df = pd.read_csv(google_news_path, sep='|').loc[:, ['text', 'label', 'lang', 'font']]
fpb_df = pd.read_csv(financial_phrase_bank_path, sep='|', index_col=0)
b3_df = pd.read_csv(b3_path, sep='|')

# %%
infomoney_df
# Out:
#                                                    text  label  lang  \
# 0     Secretário da Fazenda diz que medidas do gover...      2  ptbr
# 1     Trade hoje: Mesmo acima dos 100 mil, Ibovespa ...      0  ptbr
# 2     Com alta de preços e crédito escasso, aumenta ...      1  ptbr
# 3     “Pelo menos há agora um aceno à disciplina fis...      1  ptbr
# 4     IR 2023: Posso ficar sem declarar um bem que f...      1  ptbr
# ...                                                 ...    ...   ...
# 1326  Lojas Renner (LREN3) reporta números fracos e ...      1  ptbr
# 1327  Lula volta a sinalizar que pode discutir auton...      1  ptbr
# 1328  Lula sobre Campos Neto: se não posso influir p...      0  ptbr
# 1329  Embraer (EMBR3) entrega 80 jatos no 4º trimest...      2  ptbr
# 1330  Lula diz que mercado está ‘muito conservador’ ...      1  ptbr
#
#            font
# 0     InfoMoney
# 1     InfoMoney
# 2     InfoMoney
# 3     InfoMoney
# 4     InfoMoney
# ...         ...
# 1326  InfoMoney
# 1327  InfoMoney
# 1328  InfoMoney
# 1329  InfoMoney
# 1330  InfoMoney
#
# [1331 rows x 4 columns]

# %%
google_news_df
# Out:
#                                                    text  label  lang  \
# 0     JPMorgan Chase to Take Over Most of First Repu...      1   eng
# 1     Fed Should End 'Crazy' Policy Tightening, Says...      0   eng
# 2     J&J's Kenvue spinoff to hit IPO market this we...      2   eng
# 3         'Bloomberg Technology' Full Show (05/01/2023)      1   eng
# 4     Two keys to establishing a comprehensive cyber...      1   eng
# ...                                                 ...    ...   ...
# 1995  Petrobras (PETR3;PETR4) traz números operacion...      1  ptbr
# 1996  Lucro da Mosaic cai 63,2% no 1º trimestre, par...      0  ptbr
# 1997  GPA (PCAR3) mira retomada das margens e estima...      2  ptbr
# 1998  GPA tem prejuízo líquido de R$ 248 milhões no ...      0  ptbr
# 1999  GPA (PCAR3): Genial cita melhora sequencial da...      2  ptbr
#
#                              font
# 0                        CoinDesk
# 1                       Bloomberg
# 2                     MarketWatch
# 3            Bloomberg Technology
# 4            Federal News Network
# ...                           ...
# 1995                Valor Investe
# 1996                   Portal DBO
# 1997                    InfoMoney
# 1998  Economia & Negócios Estadão
# 1999            spacemoney.com.br
#
# [2000 rows x 4 columns]

# %%
fpb_df
# Out:
#                                                    text  label  lang  \
# 0     A Technopolis planeja desenvolver em etapas um...      1  ptbr
# 1     A Elcoteq, empresa internacional da indústria ...      0  ptbr
# 2     Com a nova planta de produção a empresa aument...      2  ptbr
# 3     De acordo com a estratégia atualizada da empre...      2  ptbr
# 4     FINANCIAMENTO DO CRESCIMENTO DA ASPOCOMP A Asp...      2  ptbr
# ...                                                 ...    ...   ...
# 7080  Operating result for the 12-month period decre...      0   eng
# 7081  HELSINKI Thomson Financial - Shares in Cargote...      0   eng
# 7082  LONDON MarketWatch -- Share prices ended lower...      0   eng
# 7083  Operating profit fell to EUR 35.4 mn from EUR ...      0   eng
# 7084  Sales in Finland decreased by 10.5 % in Januar...      0   eng
#
#                        font
# 0     financial-phrase-bank
# 1     financial-phrase-bank
# 2     financial-phrase-bank
# 3     financial-phrase-bank
# 4     financial-phrase-bank
# ...                     ...
# 7080  financial-phrase-bank
# 7081  financial-phrase-bank
# 7082  financial-phrase-bank
# 7083  financial-phrase-bank
# 7084  financial-phrase-bank
#
# [7085 rows x 4 columns]

# %%
b3_df
# Out:
#                                                   text  label  lang font
# 0    Governo lança medidas para estimular o crédito...      2  ptbr   b3
# 1    Confira o funcionamento da bolsa de valores no...      1  ptbr   b3
# 2    Mercado financeiro hoje: atenções ficam na ata...      1  ptbr   b3
# 3    Ibovespa fecha em forte queda e dólar dispara,...      0  ptbr   b3
# 4    Produção industrial cai em fevereiro pelo 3º m...      0  ptbr   b3
# ..                                                 ...    ...   ...  ...
# 805  COE: o que é, como funciona e principais vanta...      1  ptbr   b3
# 806  LIG: o que é e como investir em Letra Imobiliá...      1  ptbr   b3
# 807  Como declarar IR de investimentos feitos no ex...      1  ptbr   b3
# 808  Quais as diferenças entre renda fixa e variáve...      1  ptbr   b3
# 809  Investimentos isentos de IR: quais são e como ...      1  ptbr   b3
#
# [810 rows x 4 columns]

# %%
df = pd.concat([infomoney_df, google_news_df, fpb_df, b3_df], axis=0)
df = df.reset_index(drop=True)
df
# Out:
#                                                     text  label  lang  \
# 0      Secretário da Fazenda diz que medidas do gover...      2  ptbr
# 1      Trade hoje: Mesmo acima dos 100 mil, Ibovespa ...      0  ptbr
# 2      Com alta de preços e crédito escasso, aumenta ...      1  ptbr
# 3      “Pelo menos há agora um aceno à disciplina fis...      1  ptbr
# 4      IR 2023: Posso ficar sem declarar um bem que f...      1  ptbr
# ...                                                  ...    ...   ...
# 11221  COE: o que é, como funciona e principais vanta...      1  ptbr
# 11222  LIG: o que é e como investir em Letra Imobiliá...      1  ptbr
# 11223  Como declarar IR de investimentos feitos no ex...      1  ptbr
# 11224  Quais as diferenças entre renda fixa e variáve...      1  ptbr
# 11225  Investimentos isentos de IR: quais são e como ...      1  ptbr
#
#             font
# 0      InfoMoney
# 1      InfoMoney
# 2      InfoMoney
# 3      InfoMoney
# 4      InfoMoney
# ...          ...
# 11221         b3
# 11222         b3
# 11223         b3
# 11224         b3
# 11225         b3
#
# [11226 rows x 4 columns]

# %%
# 0: negativo
# 1: neutro
# 2: positivo
df['label'].value_counts()
# Out:
# 1    6187
# 2    2962
# 0    2077
# Name: label, dtype: int64

# %% [markdown]
# # Remoção de stopwords e caractere '|'

# %%
df['text'] = df['text'].apply(lambda text: text.replace('|', '').replace('\n', ''))

# %%
stopwords_en = set(stopwords.words('english'))
stopwords_pt = set(stopwords.words('portuguese'))

# %%
def remove_stopwords(text, lang):
    if lang == 'eng':
        stopwords_set = stopwords_en
    elif lang == 'ptbr':
        stopwords_set = stopwords_pt

    words = word_tokenize(text)
    filtered_words = [word for word in words if word.lower() not in stopwords_set]
    return ' '.join(filtered_words)

def remove_stopwords_from_df(df):
    df['cleaned_text'] = df.apply(lambda row: remove_stopwords(row['text'], row['lang']), axis=1)
    return df

# %%
df = remove_stopwords_from_df(df)
df
# Out:
#                                                     text  label  lang  \
# 0      Secretário da Fazenda diz que medidas do gover...      2  ptbr
# 1      Trade hoje: Mesmo acima dos 100 mil, Ibovespa ...      0  ptbr
# 2      Com alta de preços e crédito escasso, aumenta ...      1  ptbr
# 3      “Pelo menos há agora um aceno à disciplina fis...      1  ptbr
# 4      IR 2023: Posso ficar sem declarar um bem que f...      1  ptbr
# ...                                                  ...    ...   ...
# 11221  COE: o que é, como funciona e principais vanta...      1  ptbr
# 11222  LIG: o que é e como investir em Letra Imobiliá...      1  ptbr
# 11223  Como declarar IR de investimentos feitos no ex...      1  ptbr
# 11224  Quais as diferenças entre renda fixa e variáve...      1  ptbr
# 11225  Investimentos isentos de IR: quais são e como ...      1  ptbr
#
#             font                                       cleaned_text
# 0      InfoMoney  Secretário Fazenda diz medidas governo abrirão...
# 1      InfoMoney  Trade hoje : acima 100 mil , Ibovespa segue te...
# 2      InfoMoney  alta preços crédito escasso , aumenta busca ca...
# 3      InfoMoney  “ menos agora aceno disciplina fiscal ” , diz ...
# 4      InfoMoney  IR 2023 : Posso ficar declarar bem vendido fal...
# ...          ...                                                ...
# 11221         b3              COE : , funciona principais vantagens
# 11222         b3         LIG : investir Letra Imobiliária Garantida
# 11223         b3        declarar IR investimentos feitos exterior ?
# 11224         b3     Quais diferenças renda fixa variável ? Entenda
# 11225         b3         Investimentos isentos IR : quais funcionam
#
# [11226 rows x 5 columns]

# %%
df['raw_text'] = df['text']
df['text'] = df['cleaned_text']
df.drop(columns=['cleaned_text'], inplace=True)
df
# Out:
#                                                     text  label  lang  \
# 0      Secretário Fazenda diz medidas governo abrirão...      2  ptbr
# 1      Trade hoje : acima 100 mil , Ibovespa segue te...      0  ptbr
# 2      alta preços crédito escasso , aumenta busca ca...      1  ptbr
# 3      “ menos agora aceno disciplina fiscal ” , diz ...      1  ptbr
# 4      IR 2023 : Posso ficar declarar bem vendido fal...      1  ptbr
# ...                                                  ...    ...   ...
# 11221              COE : , funciona principais vantagens      1  ptbr
# 11222         LIG : investir Letra Imobiliária Garantida      1  ptbr
# 11223        declarar IR investimentos feitos exterior ?      1  ptbr
# 11224     Quais diferenças renda fixa variável ? Entenda      1  ptbr
# 11225         Investimentos isentos IR : quais funcionam      1  ptbr
#
#             font                                           raw_text
# 0      InfoMoney  Secretário da Fazenda diz que medidas do gover...
# 1      InfoMoney  Trade hoje: Mesmo acima dos 100 mil, Ibovespa ...
# 2      InfoMoney  Com alta de preços e crédito escasso, aumenta ...
# 3      InfoMoney  “Pelo menos há agora um aceno à disciplina fis...
# 4      InfoMoney  IR 2023: Posso ficar sem declarar um bem que f...
# ...          ...                                                ...
# 11221         b3  COE: o que é, como funciona e principais vanta...
# 11222         b3  LIG: o que é e como investir em Letra Imobiliá...
# 11223         b3  Como declarar IR de investimentos feitos no ex...
# 11224         b3  Quais as diferenças entre renda fixa e variáve...
# 11225         b3  Investimentos isentos de IR: quais são e como ...
#
# [11226 rows x 5 columns]

# %% [markdown]
# # Divisão de treino, validação e teste

# %%
train_temp_ratio = 0.7
val_test_ratio = 0.5

train_df, test_df = train_test_split(df, test_size=1-train_temp_ratio, stratify=df[['label', 'lang']], random_state=seed)
test_df, val_df = train_test_split(test_df, test_size=val_test_ratio, stratify=test_df[['label', 'lang']], random_state=seed)

# %%
# Train_df info
print(f'Train size: {len(train_df)} ({len(train_df)/len(df)*100:.2f}%)\n')
print(f"Train labels ratio:\n{train_df['label'].value_counts()/len(train_df)}\n")
print(f"Train languages ratio:\n{train_df['lang'].value_counts()/len(train_df)}\n")
print(f"Train fonts ratio:\n{train_df['font'].value_counts()/len(train_df)}")
print('---------------------------------------------------------------------------------')
# Val_df info
print(f'Validation size: {len(val_df)} ({len(val_df)/len(df)*100:.2f}%)\n')
print(f"Validation labels ratio:\n{val_df['label'].value_counts()/len(val_df)}\n")
print(f"Validation languages ratio:\n{val_df['lang'].value_counts()/len(val_df)}\n")
print(f"Validation fonts ratio:\n{val_df['font'].value_counts()/len(val_df)}")
print('---------------------------------------------------------------------------------')
# Test_df info
print(f'Test size: {len(test_df)} ({len(test_df)/len(df)*100:.2f}%)\n')
print(f"Test labels ratio:\n{test_df['label'].value_counts()/len(test_df)}\n")
print(f"Test languages ratio:\n{test_df['lang'].value_counts()/len(test_df)}\n")
print(f"Test fonts ratio:\n{test_df['font'].value_counts()/len(test_df)}")
# Out:
# Train size: 7858 (70.00%)
#
# Train labels ratio:
# 1    0.551158
# 2    0.263808
# 0    0.185034
# Name: label, dtype: float64
#
# Train languages ratio:
# ptbr    0.689107
# eng     0.310893
# Name: lang, dtype: float64
#
# Train fonts ratio:
# financial-phrase-bank           0.631204
# InfoMoney                       0.123059
# b3                              0.071519
# Yahoo Finance                   0.010053
# CNBC                            0.008654
#                                   ...
# JC Online                       0.000127
# Contábeis                       0.000127
# Raw Story                       0.000127
# Kiplinger's Personal Finance    0.000127
# ECO                             0.000127
# Name: font, Length: 432, dtype: float64
# ---------------------------------------------------------------------------------
# Validation size: 1684 (15.00%)
#
# Validation labels ratio:
# 1    0.551069
# 2    0.263658
# 0    0.185273
# Name: label, dtype: float64
#
# Validation languages ratio:
# ptbr    0.690024
# eng     0.309976
# Name: lang, dtype: float64
#
# Validation fonts ratio:
# financial-phrase-bank    0.640143
# InfoMoney                0.125297
# b3                       0.073040
# CNBC                     0.008907
# Yahoo Finance            0.007126
#                            ...
# Estado de Minas          0.000594
# Jornal do Comércio       0.000594
# UnHerd                   0.000594
# KRLD                     0.000594
# Business Today           0.000594
# Name: font, Length: 145, dtype: float64
# ---------------------------------------------------------------------------------
# Test size: 1684 (15.00%)
#
# Test labels ratio:
# 1    0.551069
# 2    0.264252
# 0    0.184679
# Name: label, dtype: float64
#
# Test languages ratio:
# ptbr    0.688836
# eng     0.311164
# Name: lang, dtype: float64
#
# Test fonts ratio:
# financial-phrase-bank    0.621734
# InfoMoney                0.121734
# b3                       0.074228
# CNBC                     0.007126
# Investing.com Brasil     0.006532
#                            ...
# KHOU.com                 0.000594
# G1                       0.000594
# HYPEBEAST                0.000594
# VEJA                     0.000594
# CriptoFácil              0.000594
# Name: font, Length: 175, dtype: float64

# %%
train_df
# Out:
#                                                     text  label  lang  \
# 4779   Veracel preparando recurso questão pediu tribu...      1  ptbr
# 8703   Changes announced today effective close tradin...      1   eng
# 7087   prédio abrigará laboratórios teste desenvolvim...      1  ptbr
# 7983   lucro ação ( EPS ) 2005 diminuiu € 1.87 € 1.89...      0  ptbr
# 10318  Pretax profit decreased EUR 33.8 mn EUR 40.8 m...      0   eng
# ...                                                  ...    ...   ...
# 9347   Cohen & Steers , Inc. : 5 534 626 shares repre...      1   eng
# 2943   Vista Alegre passa prejuízos lucros primeiro t...      2  ptbr
# 9622   number class shares remains unchanged 9,526,08...      1   eng
# 6135   partir 2 julho 2007 , segmentos capitalização ...      1  ptbr
# 9619   new location n't change Wellmont store air tra...      1   eng
#
#                         font  \
# 4779   financial-phrase-bank
# 8703   financial-phrase-bank
# 7087   financial-phrase-bank
# 7983   financial-phrase-bank
# 10318  financial-phrase-bank
# ...                      ...
# 9347   financial-phrase-bank
# 2943                     ECO
# 9622   financial-phrase-bank
# 6135   financial-phrase-bank
# 9619   financial-phrase-bank
#
#                                                 raw_text
# 4779   A Veracel está preparando um recurso na questã...
# 8703   Changes being announced today will be effectiv...
# 7087   O prédio abrigará laboratórios de teste e dese...
# 7983   O lucro por ação (EPS) em 2005 diminuiu para €...
# 10318  Pretax profit decreased to EUR 33.8 mn from EU...
# ...                                                  ...
# 9347   Cohen & Steers , Inc. : 5 534 626 shares repre...
# 2943   Vista Alegre passa de prejuízos a lucros no pr...
# 9622   The number of class A shares remains unchanged...
# 6135   A partir de 2 de julho de 2007, os segmentos d...
# 9619   The new location is n't the only change Wellmo...
#
# [7858 rows x 5 columns]

# %%
val_df
# Out:
#                                                     text  label  lang  \
# 8402   Revenue July September grew 21 percent EURO 2....      2   eng
# 6269   recente entrevista Financial Times ( FT ) , pr...      1  ptbr
# 2902   Grande plano Santander permitirá maior oferta ...      2  ptbr
# 6275   conexão negócio , Digia vai empregar 19 pessoa...      1  ptbr
# 6835   ALEXANDRIA , Va. , 19 novembro - Erkki Aho , E...      1  ptbr
# ...                                                  ...    ...   ...
# 10626  Mercado Morning Call Safra : PIB balanço Petro...      1  ptbr
# 7142   grupo EA Reng registrou vendas aproximadamente...      1  ptbr
# 10952  Brasil x Coreia Sul : adversário vantagens ind...      0  ptbr
# 7609   `` contrato licença Nokia Corp. expira parcial...      1  ptbr
# 5737   final agosto , Sampo maior acionista Nordea pa...      1  ptbr
#
#                         font  \
# 8402   financial-phrase-bank
# 6269   financial-phrase-bank
# 2902     Seu Crédito Digital
# 6275   financial-phrase-bank
# 6835   financial-phrase-bank
# ...                      ...
# 10626                     b3
# 7142   financial-phrase-bank
# 10952                     b3
# 7609   financial-phrase-bank
# 5737   financial-phrase-bank
#
#                                                 raw_text
# 8402   Revenue from July to September grew 21 percent...
# 6269   Em uma recente entrevista ao Financial Times (...
# 2902   Grande plano do Santander permitirá maior ofer...
# 6275   Em conexão com o negócio, a Digia vai empregar...
# 6835   ALEXANDRIA, Va., 19 de novembro - Erkki Aho, E...
# ...                                                  ...
# 10626  Mercado e Morning Call Safra: PIB e balanço da...
# 7142   O grupo EA Reng registrou vendas de aproximada...
# 10952  Brasil x Coreia do Sul: adversário tem vantage...
# 7609   `` Temos um contrato de licença com a Nokia Co...
# 5737   No final de agosto, a Sampo era o maior acioni...
#
# [1684 rows x 5 columns]

# %%
test_df
# Out:
#                                                    text  label  lang  \
# 1966  Fed Rate Decision Today : Live Updates Policy ...      1   eng
# 5610  ADP News - 25 fevereiro 2009 - fabricante finl...      2  ptbr
# 6107  ALEXANDRIA , Va. , 19 dezembro - Patente Estad...      1  ptbr
# 7821  outras ações incluem corte caros turnos fim se...      1  ptbr
# 3850  pedido inclui serviços inicialização comission...      1  ptbr
# ...                                                 ...    ...   ...
# 2904  Rede principal SUI entra operação , token desa...      0  ptbr
# 6249  revisor oficial contas British Columbia Albert...      1  ptbr
# 1153  Petrobras ( PETR4 ) leva petróleo Cubatão navi...      1  ptbr
# 5795  membro Conselho várias empresas acionista rede...      1  ptbr
# 1368  3-month T-bill rate touches highest level sinc...      0   eng
#
#                        font                                           raw_text
# 1966              Bloomberg  Fed Rate Decision Today: Live Updates on Polic...
# 5610  financial-phrase-bank  ADP News - 25 de fevereiro de 2009 - A fabrica...
# 6107  financial-phrase-bank  ALEXANDRIA, Va., 19 de dezembro - Patente dos ...
# 7821  financial-phrase-bank  As outras ações incluem o corte dos caros turn...
# 3850  financial-phrase-bank  O pedido também inclui serviços de inicializaç...
# ...                     ...                                                ...
# 2904            CriptoFácil  Rede principal da SUI entra em operação, token...
# 6249  financial-phrase-bank  Ele é um revisor oficial de contas em British ...
# 1153              InfoMoney  Petrobras (PETR4) leva petróleo a Cubatão por ...
# 5795  financial-phrase-bank  Ele é membro do Conselho de várias empresas e ...
# 1368            MarketWatch  3-month T-bill rate touches highest level sinc...
#
# [1684 rows x 5 columns]

# %%
df.to_csv('datasets/df.csv', sep='|', index=False)
train_df.to_csv('datasets/train_df.csv', sep='|', index=False)
val_df.to_csv('datasets/val_df.csv', sep='|', index=False)
test_df.to_csv('datasets/test_df.csv', sep='|', index=False)

# %%
import json

output_file = 'datasets/df.json'

# Convertendo o dataframe para o formato esperado pelo Label Studio
converted_data = []

for index, row in df.iterrows():
    item = {
        'id': index,
        'data': {
            'text': row['text'],
            'label': row['label'],
            'lang': row['lang'],
            'font': row['font'],
            'raw_text': row['raw_text']
        }
    }
    converted_data.append(item)

# Salvando o arquivo convertido
with open(output_file, 'w', encoding='utf-8') as outfile:
    json.dump(converted_data, outfile, ensure_ascii=False, indent=4)
